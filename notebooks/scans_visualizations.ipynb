# %%
import nilearn as nl
import pandas as pd
from os import path
from nilearn import plotting
import nibabel as nib

# %%
plotting.plot_img('/galitylab/data/studyforrest-data/derivative/aligned_mri/sub-01/in_bold3Tp2/sub-01_task-avmovie_run-1_bold.nii.gz')
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 plotting.plot_img('/galitylab/data/studyforrest-data/derivative/aligned_mri/sub-01/in_bold3Tp2/sub-01_task-avmovie_run-1_bold.nii.gz')
#
# File /galitylab/installations/idan/miniconda3/envs/fmri/lib/python3.10/site-packages/nilearn/plotting/img_plotting.py:264, in plot_img(img, cut_coords, output_file, display_mode, figure, axes, title, threshold, annotate, draw_cross, black_bg, colorbar, cbar_tick_format, resampling_interpolation, bg_img, vmin, vmax, **kwargs)
#     221 @fill_doc
#     222 def plot_img(img, cut_coords=None, output_file=None, display_mode='ortho',
#     223              figure=None, axes=None, title=None, threshold=None,
#    (...)
#     226              resampling_interpolation='continuous',
#     227              bg_img=None, vmin=None, vmax=None, **kwargs):
# ...

# %%
plotting.plot_img('/galitylab/data/studyforrest-data/derivative/visual_areas/sub-01/rois/lEBA_2_mask.nii.gz')
